# %% [markdown]
# **POST TEST**

# %% [markdown]
# **Data Cleaning**

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# **Menambahkan File IrisData.csv**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f529778-d621-4468-8651-4b0c662a0d30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f529778-d621-4468-8651-4b0c662a0d30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Memanggil Data**

# %%
dataset = pd.read_csv("IrisData.csv")

# %% [markdown]
# **Melihat Isi File**

# %%
dataset
# Out:
#                                                   iris
# 0    sepal.length;sepal.width;petal.length;petal.wi...
# 1                                   5.1;;1.4;.2;Setosa
# 2                                  4.9;3;1.4;.2;Setosa
# 3                                4.7;3.2;1.3;.2;Setosa
# 4                                4.6;3.1;1.5;.2;Setosa
# ..                                                 ...
# 146                            6.7;3;5.2;2.3;Virginica
# 147                            6.3;2.5;5;1.9;Virginica
# 148                              6.5;3;5.2;2;Virginica
# 149                             6.2;3.4;;2.3;Virginica
# 150                            5.9;3;5.1;1.8;Virginica
#
# [151 rows x 1 columns]

# %% [markdown]
# **Melihat Report Profil Dokumen**

# %%
dataset.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-10-10 07:38:02.881467&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# **Perbaiki struktur data**

# %%
import pandas as pd

df = pd.read_csv("IrisData.csv", sep=";", skiprows=1)

print(df.head())
print(df.info())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          NaN           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  149 non-null    float64
#  1   sepal.width   146 non-null    float64
#  2   petal.length  143 non-null    float64
#  3   petal.width   146 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# **Ubah tipe data numerik**

# %%
for col in df.columns[:-1]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  149 non-null    float64
#  1   sepal.width   146 non-null    float64
#  2   petal.length  143 non-null    float64
#  3   petal.width   146 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          NaN           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# **Eksplorasi Data**

# %% [markdown]
# Informasi Umum

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  149 non-null    float64
#  1   sepal.width   146 non-null    float64
#  2   petal.length  143 non-null    float64
#  3   petal.width   146 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# jumlah data hilang untuk setiap atribute

# %%
a = pd.isnull(dataset).sum()
print (a)
# Out:
# iris    0
# dtype: int64

# %% [markdown]
# Statistik Deskriptif

# %%
print(df.describe())

print("\nDistribusi kategori 'variety':")
print(df['variety'].value_counts())
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    149.000000   146.000000    143.000000   146.000000
# mean       5.853691     3.050000      3.800000     1.226027
# std        0.821051     0.438217      1.753628     0.754943
# min        4.400000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.325000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# Distribusi kategori 'variety':
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Visualisasi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df, hue="variety")
plt.show()

# %% [markdown]
# **Transformasi Data**

# %%
from sklearn import datasets
IrisData = datasets.load_iris()

# %% [markdown]
# **Normalisasi dengan mean 0, SD 1 (Tranfsormasi Z-Score)**

# %% [markdown]
# Fungsi Scale

# %%
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import scale

iris = datasets.load_iris()

df_scaled = pd.DataFrame(scale(iris.data), columns=iris.feature_names)
df_scaled['target'] = iris.target

df_scaled.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Fungsi StandardScaler dan Transform

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = df.iloc[:, :-1]
X_scaled = scaler.fit_transform(X)

df_standardized = pd.DataFrame(X_scaled, columns=iris.feature_names)
df_standardized['target'] = df['target']
df_standardized.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_standardized.describe().loc[['mean', 'std']]
# Out:
#       sepal length (cm)  sepal width (cm)  petal length (cm)  \
# mean      -1.468455e-15     -1.823726e-15      -1.610564e-15
# std        1.003350e+00      1.003350e+00       1.003350e+00
#
#       petal width (cm)    target
# mean     -9.473903e-16  1.000000
# std       1.003350e+00  0.819232

# %%
X_scaled = scaler.fit_transform(df.iloc[:, :-1])

# %%
X_train = df.iloc[:100, :-1]
X_test = df.iloc[100:, :-1]

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
df_standardized = pd.DataFrame(X_scaled, columns=iris.feature_names)
df_standardized['target'] = df['target']
df_standardized.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# **Normalisasi min-max**

# %% [markdown]
# MinMaxScaler atau MaxAbsScaler

# %%
iris = datasets.load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.preprocessing import MinMaxScaler
minmax_scaler = MinMaxScaler()

# %%
X = df.iloc[:, :-1]
X_minmax = minmax_scaler.fit_transform(X)

df_minmax = pd.DataFrame(X_minmax, columns=iris.feature_names)
df_minmax['target'] = df['target']
df_minmax.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_minmax.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            0.428704          0.440556           0.467458
# std             0.230018          0.181611           0.299203
# min             0.000000          0.000000           0.000000
# 25%             0.222222          0.333333           0.101695
# 50%             0.416667          0.416667           0.567797
# 75%             0.583333          0.541667           0.694915
# max             1.000000          1.000000           1.000000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           0.458056    1.000000
# std            0.317599    0.819232
# min            0.000000    0.000000
# 25%            0.083333    0.000000
# 50%            0.500000    1.000000
# 75%            0.708333    2.000000
# max            1.000000    2.000000
